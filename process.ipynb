# %%
import json

# %%
with open('data/instance-1.json', 'r') as f:
    data = json.load(f)

# %%
node =data['nodes']
for n in node:
    n['name'] = ''

# %%
node
# Out:
# [{'id': '0',
#   'name': '',
#   'symbolSize': 19.12381,
#   'x': -266.82776,
#   'y': 299.6904,
#   'value': 28.685715,
#   'category': 0},
#  {'id': '1',
#   'name': '',
#   'symbolSize': 26.5,
#   'x': -418.08344,
#   'y': 46.8853,
#   'value': 4,
#   'category': 0},
#  {'id': '2',
#   'name': '',
#   'symbolSize': 61.323809333,
#   'x': -22.76357,
#   'y': 245.29176,
#   'value': 9.485714,
#   'category': 1},
#  {'id': '3',
#   'name': '',
#   'symbolSize': 6.323809333333333,
#   'x': 242.82404,
#   'y': -235.26283,
#   'value': 9.485714,
#   'category': 1},
#  {'id': '4',
#   'name': '',
#   'symbolSize': 2.6666666666666665,
#   'x': -79.3,
#   'y': 429.06,
#   'value': 4,
#   'category': 2},
#  {'id': '5',
#   'name': '',
#   'symbolSize': 26.666666666666664,
#   'x': -417.26337,
#   'y': 406.03506,
#   'value': 4,
#   'category': 0},
#  {'id': '6',
#   'name': '',
#   'symbolSize': 22.666666666666668,
#   'x': -332.6012,
#   'y': 485.16974,
#   'value': 4,
#   'category': 0},
# ...
